# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('./Dataset/airbus_crash_passengers.csv')

# %%
df.head(8)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass                 Name     Sex  \
# 0           0            1         1       2   Williams, Patricia  female
# 1           1            2         0       2  Williams, Elizabeth  female
# 2           2            3         1       1     Jones, Elizabeth  female
# 3           3            4         0       3   Johnson, Elizabeth  female
# 4           4            5         0       1       Smith, Barbara  female
# 5           5            6         1       3   Johnson, Elizabeth  female
# 6           6            7         1       2      Johnson, Robert    male
# 7           7            8         1       1          Jones, Mary  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  36.0      2      0  37938Q  104.30   B86        C
# 1  28.3      0      2  44760E  116.58   A96        S
# 2  37.8      1      3  55745C   24.50   NaN        S
# 3  48.3      3      2  42018L  136.86    E4        C
# 4  27.2      4      1  47353F   89.96   F92        S
# 5  27.2      0      3  67433R  130.82   NaN        Q
# 6  49.0      1      2  49651T   37.88   D46        S
# 7  39.2      0      3  95717Q   36.50   C59        S

# %% [markdown]
# # Categorical Data

# %%
# a. countplot

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(df['Pclass'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(df['Sex'])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %% [markdown]
# # Pie Chart

# %%
df['Survived'].value_counts().plot(kind = 'pie', autopct = '%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind = 'pie', autopct = '%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# In categorocal data you either go with only pie chart or countplot

# %% [markdown]
# # Numerical Data

# %% [markdown]
# a. histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'])
# Out:
# (array([ 13.,  46.,  92., 117., 119.,  65.,  35.,  10.,   2.,   1.]),
#  array([ 1.  ,  8.52, 16.04, 23.56, 31.08, 38.6 , 46.12, 53.64, 61.16,
#         68.68, 76.2 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# b. Displot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\anshu\AppData\Local\Temp\ipykernel_23100\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# c. Boxplot

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
# Helps to find Outliers

# %%
df['Age'].min()
# Out:
# 1.0

# %%
df['Age'].max()
# Out:
# 76.2

# %%
df['Age'].mean()
# Out:
# 30.107800000000005
