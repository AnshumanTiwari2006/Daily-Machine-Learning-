# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))
# Assume user input
test_input2= np.array([3, 'female', 45.0, 0,0, 11.5,'Q'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
