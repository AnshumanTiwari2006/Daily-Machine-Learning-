# %%
pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 527.6 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 527.6 kB/s eta 0:00:02
#    ----------------------- ---------------- 0.8/1.4 MB 543.4 kB/s eta 0:00:02
#    ----------------------- ---------------- 0.8/1.4 MB 543.4 kB/s eta 0:00:02
#    ------------------------------ --------- 1.0/1.4 MB 547.1 kB/s eta 0:00:01
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df = df[['sepal_length', 'petal_length', 'species']]
df.head()
# Out:
#    sepal_length  petal_length species
# 0           5.1           1.4  setosa
# 1           4.9           1.4  setosa
# 2           4.7           1.3  setosa
# 3           4.6           1.5  setosa
# 4           5.0           1.4  setosa

# %%
X = df.iloc[:, 0:2]
y = df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %%
clf = LogisticRegression()  # Uses defaults
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9666666666666667

# %%
pd.DataFrame(confusion_matrix(y_test, y_pred))
# Out:
#     0  1  2
# 0  14  0  0
# 1   0  7  1
# 2   0  0  8

# %%
query = np.array([[3.4, 2.7]])
clf.predict_proba(query)
# Out:
# C:\Users\Anshuman Tiwari\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[7.25865651e-01, 2.73720718e-01, 4.13631316e-04]])

# %%
clf.predict(query)
# Out:
# C:\Users\Anshuman Tiwari\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['setosa'], dtype=object)

# %%
# 1. Encode string labels to integers
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# 2. Train a classifier on the INTEGER labels for plotting
clf_plot = LogisticRegression()
clf_plot.fit(X, y_encoded)  # Fit on full data for the visualization

# 3. Plot using the integer-trained classifier
plot_decision_regions(X.values, y_encoded, clf=clf_plot, legend=2)

plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')  # Fixed from xlabel
plt.title('Logistic Regression Decision Regions')
plt.show()
# Out:
# C:\Users\Anshuman Tiwari\AppData\Roaming\Python\Python314\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
