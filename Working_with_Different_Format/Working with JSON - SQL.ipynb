# %%
import pandas as pd

# %%
# Working with JSON

# %%
pd.read_json('./Dataset/train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json("URL")

# %%
# Working with SQL

# %%
# !pip install mysql.connector
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host = 'localhost', user = 'root', password = '', database = 'world')

# %%
pd.read_sql_query("SELECT * FROM city WHERE Population > 170000", conn)
# Out:
# C:\Users\anshu\AppData\Local\Temp\ipykernel_22968\983424863.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE Population > 170000", conn)
#         ID         Name CountryCode       District  Population
# 0        1        Kabul         AFG          Kabol     1780000
# 1        2     Qandahar         AFG       Qandahar      237500
# 2        3        Herat         AFG          Herat      186800
# 3        5    Amsterdam         NLD  Noord-Holland      731200
# 4        6    Rotterdam         NLD   Zuid-Holland      593321
# ...    ...          ...         ...            ...         ...
# 2002  3915       Oxnard         USA     California      170358
# 2003  4068       Harare         ZWE         Harare     1410000
# 2004  4069     Bulawayo         ZWE       Bulawayo      621742
# ...

# %%
pd.read_sql_query("SELECT * FROM country WHERE LifeExpectancy > 60", conn)
# Out:
# C:\Users\anshu\AppData\Local\Temp\ipykernel_22968\4278207049.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE LifeExpectancy > 60", conn)
#     Code                  Name      Continent           Region  SurfaceArea  \
# 0    ABW                 Aruba  North America        Caribbean        193.0
# 1    AIA              Anguilla  North America        Caribbean         96.0
# 2    ALB               Albania         Europe  Southern Europe      28748.0
# 3    AND               Andorra         Europe  Southern Europe        468.0
# 4    ANT  Netherlands Antilles  North America        Caribbean        800.0
# ..   ...                   ...            ...              ...          ...
# 162  VIR  Virgin Islands, U.S.  North America        Caribbean        347.0
# ...

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'NLD'", conn)
# Out:
# C:\Users\anshu\AppData\Local\Temp\ipykernel_22968\3395324654.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode LIKE 'NLD'", conn)
#     ID              Name CountryCode       District  Population
# 0    5         Amsterdam         NLD  Noord-Holland      731200
# 1    6         Rotterdam         NLD   Zuid-Holland      593321
# 2    7              Haag         NLD   Zuid-Holland      440900
# 3    8           Utrecht         NLD        Utrecht      234323
# 4    9         Eindhoven         NLD  Noord-Brabant      201843
# 5   10           Tilburg         NLD  Noord-Brabant      193238
# 6   11         Groningen         NLD      Groningen      172701
# 7   12             Breda         NLD  Noord-Brabant      160398
# ...
